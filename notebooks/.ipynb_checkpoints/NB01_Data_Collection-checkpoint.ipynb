# %% [markdown]
# ## Data Collection Notebook

# %%
import json
import os

import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Reading csv
#
# </h3>
#
#
#
# </div>

# %%
rurality_path = os.path.abspath(os.path.join("NBO1_Data_Collection.ipynb/"+"../.."+"/data/raw/attainment_by_rurality.csv"))
chars_path = os.path.abspath(os.path.join("NBO1_Data_Collection.ipynb/"+"../.."+"/data/raw/attainment_by_characteristics.csv"))

# %%
rurality_df = pd.read_csv(rurality_path)
chars_df = pd.read_csv(chars_path)

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Pulling important columns only
#
# </h3>
#
#
#
# </div>

# %%
chars_df = chars_df[["time_period", "version", "region_name", "characteristic_type", "characteristic_value",
    "establishment_type", "number_of_students_acad", "number_of_students_alev", "number_of_students_potential",
    "aps_per_entry_grade_acad", "aps_per_entry_grade_alev", "pc_achieving_3_astar_to_a_alev"]]
chars_df
# Out:
#        time_period  version               region_name characteristic_type  \
# 0           201920    Final                South East                 Sex
# 1           201920    Final           East of England                 Sex
# 2           201920    Final                South East                 Sex
# 3           201920    Final                North West                 Sex
# 4           201920    Final             East Midlands                 Sex
# ...            ...      ...                       ...                 ...
# 21029       202324  Revised                South East        All Students
# 21030       202324  Revised           East of England        All Students
# 21031       202324  Revised                    London        All Students
# 21032       202324  Revised                North West        All Students
# 21033       202324  Revised  Yorkshire and The Humber        All Students
#
#             characteristic_value                     establishment_type  \
# ...

# %%
chars_df.isna().sum()
# Out:
# time_period                       0
# version                           0
# region_name                       0
# characteristic_type               0
# characteristic_value              0
# establishment_type                0
# number_of_students_acad           0
# number_of_students_alev           0
# number_of_students_potential      0
# aps_per_entry_grade_acad          0
# aps_per_entry_grade_alev          0
# pc_achieving_3_astar_to_a_alev    0
# dtype: int64

# %%
chars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21034 entries, 0 to 21033
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   time_period                     21034 non-null  int64
#  1   version                         21034 non-null  object
#  2   region_name                     21034 non-null  object
#  3   characteristic_type             21034 non-null  object
#  4   characteristic_value            21034 non-null  object
#  5   establishment_type              21034 non-null  object
#  6   number_of_students_acad         21034 non-null  object
#  7   number_of_students_alev         21034 non-null  object
#  8   number_of_students_potential    21034 non-null  object
#  9   aps_per_entry_grade_acad        21034 non-null  object
#  10  aps_per_entry_grade_alev        21034 non-null  object
#  11  pc_achieving_3_astar_to_a_alev  21034 non-null  object
# ...

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Dealing with custom null values "z", "x" and "c" and column types to indentify actual nulls
#
# </h3>
#
#
#
# </div>

# %%
def setNulls(x):
    if x in ["z", "x", "c"]:
        return np.nan
    else:
        try:
            return pd.to_numeric(x)
        except (ValueError, TypeError):
            return x

chars_df = chars_df.map(setNulls)

chars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21034 entries, 0 to 21033
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   time_period                     21034 non-null  int64
#  1   version                         21034 non-null  object
#  2   region_name                     21034 non-null  object
#  3   characteristic_type             21034 non-null  object
#  4   characteristic_value            21034 non-null  object
#  5   establishment_type              21034 non-null  object
#  6   number_of_students_acad         20840 non-null  float64
#  7   number_of_students_alev         20830 non-null  float64
#  8   number_of_students_potential    21009 non-null  float64
#  9   aps_per_entry_grade_acad        20363 non-null  object
#  10  aps_per_entry_grade_alev        20346 non-null  object
#  11  pc_achieving_3_astar_to_a_alev  20399 non-null  float64
# ...

# %%
chars_df.isna().sum()
# Out:
# time_period                         0
# version                             0
# region_name                         0
# characteristic_type                 0
# characteristic_value                0
# establishment_type                  0
# number_of_students_acad           194
# number_of_students_alev           204
# number_of_students_potential       25
# aps_per_entry_grade_acad          671
# aps_per_entry_grade_alev          688
# pc_achieving_3_astar_to_a_alev    635
# dtype: int64

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Giving functional order to grade letters A*, A, B etc.
#
# </h3>
#
#
#
# </div>

# %%
chars_df["aps_per_entry_grade_alev"].unique()
# Out:
# array(['B', 'B-', 'A-', 'B+', nan, 'C+', 'C', 'C-', 'D+', 'A', 'A*-', 'D',
#        'A+', 'A*', 'D-', 'E-', 'E+', 'E', 'U'], dtype=object)

# %%
chars_df["aps_per_entry_grade_acad"].unique()
# Out:
# array(['B', 'B-', 'A-', 'B+', nan, 'C+', 'C', 'C-', 'D+', 'A', 'A*-',
#        'A+', 'A*', 'D', 'E+', 'E-', 'D-', 'E', 'U'], dtype=object)

# %%
def setup_categorical_type(col):
    chars_df[col] = chars_df[col].fillna('N/A')
    
    grade_order = CategoricalDtype(categories=['A*', 'A*-', 'A+', 'A', 'A-',
                                               'B+', 'B', 'B-', 'C+', 'C',
                                               'C-', 'D+', 'D', 'D-', 'E+',
                                               'E', 'E-', 'U' , 'N/A'], ordered=True)
    
    chars_df[col] = chars_df[col].astype(grade_order)


setup_categorical_type(chars_df[col]) for col in ["aps_per_entry_grade_acad", "aps_per_entry_grade_alev"]


chars_df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 12
#       4     grade_order = CategoricalDtype(categories=['A*', 'A*-', 'A+', 'A', 'A-',
#       5                                                'B+', 'B', 'B-', 'C+', 'C',
#       6                                                'C-', 'D+', 'D', 'D-', 'E+',
#       7                                                'E', 'E-', 'U' , 'N/A'], ordered=True)
#       9     chars_df[col] = chars_df[col].astype(grade_order)
# ---> 12 setup_categorical_type(chars_df[col] for col in ["aps_per_entry_grade_acad", "aps_per_entry_grade_alev"])
#      15 chars_df.info()
#
# Cell In[13], line 2, in setup_categorical_type(col)
#       1 def setup_categorical_type(col):
# ----> 2     chars_df[col] = chars_df[col].fillna('N/A')
#       4     grade_order = CategoricalDtype(categories=['A*', 'A*-', 'A+', 'A', 'A-',
# ...

# %%
chars_df["characteristic_type"].unique()

# %%
chars_df[(chars_df["characteristic_type"]=="Sex")].groupby(
    ["region_name", "characteristic_value"]).agg({
    "number_of_students_acad":"sum",
    "number_of_students_alev": "sum",
    "number_of_students_potential": "sum",
    "aps_per_entry_grade_alev": "min"
    })
