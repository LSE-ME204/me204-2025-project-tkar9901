# %% [markdown]
# ## Data Collection Notebook

# %%
import json
import os
import sys

import numpy as np
import pandas as pd

sys.path.append('../..')
from final_project.scripts.data_collection_utils import set_nulls, setup_categorical_type

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Reading CSV from EES - Explore Education Statistics
#
# </h3>
#
#     - https://explore-education-statistics.service.gov.uk/data-catalogue
#
#
# </div>

# %%
rurality_path = os.path.abspath(os.path.join("NBO1_Data_Collection.ipynb/"+"../.."+"/data/raw/EES_attainment_by_rurality.csv"))
chars_path = os.path.abspath(os.path.join("NBO1_Data_Collection.ipynb/"+"../.."+"/data/raw/EES_attainment_by_characteristics.csv"))
retention_path = os.path.abspath(os.path.join("NBO1_Data_Collection.ipynb/"+"../.."+"/data/raw/EES_retention_by_region.csv"))
results_path = os.path.abspath(os.path.join("NBO1_Data_Collection.ipynb/"+"../.."+"/data/raw/EES_results_by_subject.csv"))
stem_path = os.path.abspath(os.path.join("NBO1_Data_Collection.ipynb/"+"../.."+"/data/raw/EES_stem_by_sex.csv"))

# %%
rurality_df = pd.read_csv(rurality_path)
chars_df = pd.read_csv(chars_path)
retention_df = pd.read_csv(retention_path)
results_df = pd.read_csv(results_path, low_memory=False)
stem_df = pd.read_csv(stem_path)

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Sorting out rurality_df
#
# </h3>
#
#     I will:
#     - pull the important/ useful columns
#     - deal with the custom null values "z", "x" and "c"
#     - identify actual null values
#     - give ordered categorical type to grade columns in order to perform numerical aggregation later (eg. min, max etc.)
#
# </div>

# %%
rurality_df = rurality_df[["time_period", "version", "region_name", "rurality_name", "number_of_students_acad",
                           "number_of_students_alev", "number_of_students_potential", "aps_per_entry_grade_acad",
                           "aps_per_entry_grade_alev", "pc_achieving_atleast_two_alev", "pc_achieving_3_astar_to_a_alev"]]

rurality_df
# Out:
#      time_period  version               region_name  \
# 0         201920    Final                North East
# 1         201920    Final             West Midlands
# 2         201920    Final           East of England
# 3         201920    Final             East Midlands
# 4         201920    Final                South West
# ..           ...      ...                       ...
# 310       202324  Revised                North West
# 311       202324  Revised  Yorkshire and The Humber
# 312       202324  Revised                North East
# 313       202324  Revised             West Midlands
# 314       202324  Revised           East of England
#
#                  rurality_name  number_of_students_acad  \
# 0    Urban - Major conurbation                     4444
# 1    Urban - Major conurbation                    12258
# 2    Urban - Major conurbation                     2980
# 3    Urban - Major conurbation                       47
# ...

# %%
rurality_df = rurality_df.map(set_nulls)

# %%
rurality_df = setup_categorical_type(rurality_df, "aps_per_entry_grade_acad")
rurality_df = setup_categorical_type(rurality_df, "aps_per_entry_grade_alev")

rurality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   time_period                     315 non-null    int64
#  1   version                         315 non-null    object
#  2   region_name                     315 non-null    object
#  3   rurality_name                   315 non-null    object
#  4   number_of_students_acad         315 non-null    int64
#  5   number_of_students_alev         315 non-null    int64
#  6   number_of_students_potential    315 non-null    int64
#  7   aps_per_entry_grade_acad        315 non-null    category
#  8   aps_per_entry_grade_alev        315 non-null    category
#  9   pc_achieving_atleast_two_alev   215 non-null    float64
#  10  pc_achieving_3_astar_to_a_alev  214 non-null    float64
# dtypes: category(2), float64(2), int64(4), object(3)
# memory usage: 24.3+ KB

# %%
rurality_df.groupby("region_name").apply(lambda x: x.isnull().sum(), include_groups=False)
# Out:
#                           time_period  version  rurality_name  \
# region_name
# East Midlands                       0        0              0
# East of England                     0        0              0
# London                              0        0              0
# North East                          0        0              0
# North West                          0        0              0
# South East                          0        0              0
# South West                          0        0              0
# West Midlands                       0        0              0
# Yorkshire and The Humber            0        0              0
#
#                           number_of_students_acad  number_of_students_alev  \
# region_name
# East Midlands                                   0                        0
# East of England                                 0                        0
# London                                          0                        0
# ...

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Sorting out chars_df
#
# </h3>
#
#     I will:
#     - pull the important/ useful columns
#     - deal with the custom null values "z", "x" and "c"
#     - identify actual null values
#     - give ordered categorical type to grade columns in order to perform numerical aggregation later (eg. min, max etc.)
#
# </div>

# %%
chars_df = chars_df[["time_period", "version", "region_name", "characteristic_type", "characteristic_value",
    "establishment_type", "number_of_students_acad", "number_of_students_alev", "number_of_students_potential",
    "aps_per_entry_grade_acad", "aps_per_entry_grade_alev", "pc_achieving_atleast_two_alev", "pc_achieving_3_astar_to_a_alev"]]
chars_df
# Out:
#        time_period  version               region_name characteristic_type  \
# 0           201920    Final                South East                 Sex
# 1           201920    Final           East of England                 Sex
# 2           201920    Final                South East                 Sex
# 3           201920    Final                North West                 Sex
# 4           201920    Final             East Midlands                 Sex
# ...            ...      ...                       ...                 ...
# 21029       202324  Revised                South East        All Students
# 21030       202324  Revised           East of England        All Students
# 21031       202324  Revised                    London        All Students
# 21032       202324  Revised                North West        All Students
# 21033       202324  Revised  Yorkshire and The Humber        All Students
#
#             characteristic_value                     establishment_type  \
# ...

# %%
chars_df = chars_df.map(set_nulls)

# %%
chars_df = setup_categorical_type(chars_df, "aps_per_entry_grade_acad")
chars_df = setup_categorical_type(chars_df, "aps_per_entry_grade_alev")

chars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21034 entries, 0 to 21033
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   time_period                     21034 non-null  int64
#  1   version                         21034 non-null  object
#  2   region_name                     21034 non-null  object
#  3   characteristic_type             21034 non-null  object
#  4   characteristic_value            21034 non-null  object
#  5   establishment_type              21034 non-null  object
#  6   number_of_students_acad         20840 non-null  float64
#  7   number_of_students_alev         20830 non-null  float64
#  8   number_of_students_potential    21009 non-null  float64
#  9   aps_per_entry_grade_acad        21034 non-null  category
#  10  aps_per_entry_grade_alev        21034 non-null  category
#  11  pc_achieving_atleast_two_alev   20515 non-null  float64
# ...

# %%
chars_df.groupby("time_period").apply(lambda x: x.isnull().sum(), include_groups=False)
# Out:
#              version  region_name  characteristic_type  characteristic_value  \
# time_period
# 201920             0            0                    0                     0
# 202021             0            0                    0                     0
# 202122             0            0                    0                     0
# 202223             0            0                    0                     0
# 202324             0            0                    0                     0
#
#              establishment_type  number_of_students_acad  \
# time_period
# 201920                        0                       33
# 202021                        0                       36
# 202122                        0                       56
# 202223                        0                       53
# 202324                        0                       16
#
#              number_of_students_alev  number_of_students_potential  \
# time_period
# ...

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Sorting out retention_df
#
# </h3>
#
#     I will:
#     - pull the important/ useful columns
#     - deal with the custom null values "z", "x" and "c"
#     - identify actual null values
#
# </div>

# %%
retention_df = retention_df[["time_period", "version", "region_name", "exam_cohort", "student_count_year_1",
    "student_count_year_2", "retained", "retained_and_assessed", "returned_and_retained",
    "perc_retained", "perc_retained_and_assessed", "perc_returned_and_retained"]]
retention_df
# Out:
#       time_period  version               region_name            exam_cohort  \
# 0          201920    Final                South East                A level
# 1          201920    Final           East of England                A level
# 2          201920    Final                South East                A level
# 3          201920    Final                North West                A level
# 4          201920    Final             East Midlands                A level
# ...           ...      ...                       ...                    ...
# 4040       202324  Revised                South East  Technical certificate
# 4041       202324  Revised           East of England  Technical certificate
# 4042       202324  Revised                    London  Technical certificate
# 4043       202324  Revised                North West  Technical certificate
# 4044       202324  Revised  Yorkshire and The Humber  Technical certificate
#
# ...

# %%
retention_df = retention_df.map(set_nulls)

retention_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4045 entries, 0 to 4044
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   time_period                 4045 non-null   int64
#  1   version                     4045 non-null   object
#  2   region_name                 4045 non-null   object
#  3   exam_cohort                 4045 non-null   object
#  4   student_count_year_1        4045 non-null   int64
#  5   student_count_year_2        3236 non-null   float64
#  6   retained                    3829 non-null   float64
#  7   retained_and_assessed       3829 non-null   float64
#  8   returned_and_retained       3153 non-null   float64
#  9   perc_retained               3829 non-null   float64
#  10  perc_retained_and_assessed  3829 non-null   float64
#  11  perc_returned_and_retained  3153 non-null   float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 379.3+ KB

# %%
retention_df.groupby("exam_cohort").apply(lambda x: x.isnull().sum(), include_groups=False)
# Out:
#                        time_period  version  region_name  \
# exam_cohort
# A level                          0        0            0
# Academic                         0        0            0
# Applied general                  0        0            0
# Tech level                       0        0            0
# Technical certificate            0        0            0
#
#                        student_count_year_1  student_count_year_2  retained  \
# exam_cohort
# A level                                   0                     0        14
# Academic                                  0                     0        14
# Applied general                           0                     0        18
# Tech level                                0                     0        37
# Technical certificate                     0                   809       133
#
#                        retained_and_assessed  returned_and_retained  \
# exam_cohort
# ...

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Sorting out results_df
#
# </h3>
#
#     I will:
#     - pull the important/ useful columns
#     - deal with the custom null values "z", "x" and "c"
#     - identify actual null values
#     - give ordered categorical type to grade columns in order to perform numerical aggregation later (eg. min, max etc.)
#
#
# </div>

# %%
results_df = results_df[["time_period", "version", "region_name", "qualification", "subject_name",
    "subject_area", "entry_count", "astar_grade_achieved", "a_grade_achieved", "b_grade_achieved",
    "c_grade_achieved", "d_grade_achieved", "e_grade_achieved", "u_grade_achieved",
    "astar_a_grade_achieved", "astar_b_grade_achieved", "astar_c_grade_achieved", "astar_d_grade_achieved",
    "astar_e_grade_achieved"]]

results_df
# Out:
#         time_period  version region_name qualification  \
# 0            202223  Revised      London      AS level
# 1            202223  Revised      London      AS level
# 2            202223  Revised      London      AS level
# 3            202223  Revised      London      AS level
# 4            202223  Revised      London      AS level
# ...             ...      ...         ...           ...
# 175703       202324  Revised      London      AS level
# 175704       202324  Revised      London      AS level
# 175705       202324  Revised      London      AS level
# 175706       202324  Revised      London      AS level
# 175707       202324  Revised      London      AS level
#
#                   subject_name       subject_area entry_count  \
# 0       Additional Mathematics              Maths           z
# 1       Additional Mathematics              Maths           z
# 2       Additional Mathematics              Maths           z
# ...

# %%
results_df = results_df.map(set_nulls)

results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175708 entries, 0 to 175707
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   time_period             175708 non-null  int64
#  1   version                 175708 non-null  object
#  2   region_name             175708 non-null  object
#  3   qualification           175708 non-null  object
#  4   subject_name            175708 non-null  object
#  5   subject_area            175708 non-null  object
#  6   entry_count             158397 non-null  float64
#  7   astar_grade_achieved    158397 non-null  float64
#  8   a_grade_achieved        158397 non-null  float64
#  9   b_grade_achieved        158397 non-null  float64
#  10  c_grade_achieved        158397 non-null  float64
#  11  d_grade_achieved        158397 non-null  float64
#  12  e_grade_achieved        158397 non-null  float64
# ...

# %%
results_df.groupby("region_name").apply(lambda x: x.isnull().sum(), include_groups=False)
# Out:
#                           time_period  version  qualification  subject_name  \
# region_name
# East Midlands                       0        0              0             0
# East of England                     0        0              0             0
# London                              0        0              0             0
# North East                          0        0              0             0
# North West                          0        0              0             0
# South East                          0        0              0             0
# South West                          0        0              0             0
# West Midlands                       0        0              0             0
# Yorkshire and The Humber            0        0              0             0
#
#                           subject_area  entry_count  astar_grade_achieved  \
# region_name
# East Midlands                        0         1175                  1175
# ...

# %% [markdown]
# <div style="padding: 0px 0px 0px 20px; border-left: 8px solid #ED9255; border-radius: 8px">
# <h3>
#     Sorting out stem_df
#
# </h3>
#
#     I will:
#     - pull the important/ useful columns
#     - deal with the custom null values "z", "x" and "c"
#     - identify actual null values
#
# </div>

# %%
stem_df = stem_df[["time_period", "version", "region_name", "characteristic_sex",
                   "sub_name_comb", "num_maths_science", "num_entered_comb_and_no_other_matsci",
                  "num_entered_matsci_subjects_including_comb"]]

stem_df
# Out:
#         time_period  version      region_name characteristic_sex  \
# 0            201920    Final       North West             Female
# 1            201920    Final    East Midlands             Female
# 2            201920    Final    East Midlands             Female
# 3            201920    Final  East of England             Female
# 4            201920    Final    East Midlands             Female
# ...             ...      ...              ...                ...
# 171673       202324  Revised  East of England                All
# 171674       202324  Revised    East Midlands                All
# 171675       202324  Revised       South West                All
# 171676       202324  Revised       South East                All
# 171677       202324  Revised           London                All
#
#                                             sub_name_comb num_maths_science  \
# 0       Maths & Further Maths & Biology & Chemistry & ...                 6
# ...

# %%
stem_df = stem_df.map(set_nulls)

stem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171678 entries, 0 to 171677
# Data columns (total 8 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   time_period                                 171678 non-null  int64
#  1   version                                     171678 non-null  object
#  2   region_name                                 171678 non-null  object
#  3   characteristic_sex                          171678 non-null  object
#  4   sub_name_comb                               171678 non-null  object
#  5   num_maths_science                           171678 non-null  object
#  6   num_entered_comb_and_no_other_matsci        171678 non-null  int64
#  7   num_entered_matsci_subjects_including_comb  171678 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 10.5+ MB

# %%
stem_df.groupby("region_name").apply(lambda x: x.isnull().sum(), include_groups=False)
# Out:
#                           time_period  version  characteristic_sex  \
# region_name
# East Midlands                       0        0                   0
# East of England                     0        0                   0
# London                              0        0                   0
# North East                          0        0                   0
# North West                          0        0                   0
# South East                          0        0                   0
# South West                          0        0                   0
# West Midlands                       0        0                   0
# Yorkshire and The Humber            0        0                   0
#
#                           sub_name_comb  num_maths_science  \
# region_name
# East Midlands                         0                  0
# East of England                       0                  0
# London                                0                  0
# ...
